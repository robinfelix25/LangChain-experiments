# %% [markdown]
# ## Message

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model='llama3')

# %%
from langchain_core.prompts import PromptTemplate

dynamic_prompt = PromptTemplate.from_template("What year is it? {current_year}")
response = dynamic_prompt.format(current_year=2024)
print(response)
# Out:
# What year is it? 2024

# %%
from langchain_core.prompts import PromptTemplate

user_input = input("Enter your topic here")

dynamic_prompt = PromptTemplate.from_template("Write fun facts {topic}")
ready_prompt = dynamic_prompt.invoke({'topic':user_input})
llm.invoke(ready_prompt)
# Out:
# AIMessage(content='Here are some fun facts about iPhones:\n\n**1. The First iPhone**: The original iPhone was released in 2007 and revolutionized the smartphone industry. It had a 3.5-inch touchscreen display, a 2-megapixel camera, and could store up to 4GB of music.\n\n**2. "Jesus Phone"**: When the iPhone first came out, some people started calling it the "Jesus Phone" because it was so revolutionary and game-changing. Who knew that "Jesus Phone" would become a thing?', additional_kwargs={}, response_metadata={'model': 'llama3', 'created_at': '2026-04-19T11:48:27.035801Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8733358375, 'load_duration': 3334341250, 'prompt_eval_count': 14, 'prompt_eval_duration': 2178683500, 'eval_count': 108, 'eval_duration': 3167889542, 'logprobs': None, 'model_name': 'llama3', 'model_provider': 'ollama'}, id='lc_run--019da591-f0f9-7cf0-944b-5c3a90f0a3db-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 108, 'total_tokens': 122})

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ('system', 'You are a helpfull assistanct'),
    ('human', 'Write func fact about {topic}' )
])

user_input = input("Enter a topic : ")
user_input1 = input("Enter a theme : ")

ready_prompt = prompt_template.invoke({'topic' : user_input, 'theme' : user_input1})

print(ready_prompt)

print(llm.invoke(ready_prompt).content)
# Out:
# messages=[SystemMessage(content='You are a helpfull assistanct', additional_kwargs={}, response_metadata={}), HumanMessage(content='Write func fact about ihone', additional_kwargs={}, response_metadata={})]
# Here's some fascinating facts about iPhone:
#
# 1. **First iPhone**: The first iPhone was released in 2007, revolutionizing the smartphone industry.
#
# 2. **Multi-Touch Screen**: The iPhone introduced the world to multi-touch screens, allowing users to tap, pinch, and swipe their way through apps and features.
#
# 3. **No App Store at Launch**: Initially, there was no App Store on the first-generation iPhone. Developers had to create standalone applications that users installed via USB cable or email.
#
# 4. **Original Price**: The first-generation iPhone (4GB model) launched at $499, while the 8GB model cost $599.
#
# 5. **No Video Recording**: One of the earliest limitations was no video recording capability on the original iPhone. It took until the iPhone 3GS (2009) for this feature to be added!
#
# 6. **iTunes Integration**: The iPhone's seamless integration with iTunes allowed users to easily sync their music, contacts, and more between devices.
#
# 7. **Game-Changing Cameras**: iPhone cameras have come a long way! The original had a 2MP camera, while the iPhone X (2017) introduced dual-camera technology with Portrait mode.
#
# 8. **Wireless Charging**: The iPhone X was the first to feature wireless charging capabilities, making it easier than ever to keep your device powered up.
#
# 9. **Touch ID and Face ID**: iPhone introduced Touch ID (2007) for fingerprint recognition and later added Face ID (2017), revolutionizing biometric authentication.
#
# 10. **AI-Powered Features**: With the introduction of A11 Bionic chip in 2017, iPhones started incorporating AI-powered features like Augmented Reality, Animoji, and Memoji!
#
# Which fact surprised you the most?
